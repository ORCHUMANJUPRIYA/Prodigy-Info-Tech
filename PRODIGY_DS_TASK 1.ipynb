# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Download dataset

# %%
data=pd.read_csv("E:\Kaggle datasets\migration_population.csv")

# %%
data
# Out:
#           country  year   population  pop_density  net_migration  \
# 0      Arab World  2018  419790588.0    37.372365            NaN
# 1      Arab World  2017  411898965.0    36.669804     -1408824.0
# 2      Arab World  2016  404024433.0    35.968764            NaN
# 3      Arab World  2015  396028278.0    35.256897            NaN
# 4      Arab World  2014  387907748.0    34.533978            NaN
# ...           ...   ...          ...          ...            ...
# 15571    Zimbabwe  1964    4322861.0    11.174515            NaN
# 15572    Zimbabwe  1963    4178726.0    10.801928            NaN
# 15573    Zimbabwe  1962    4039201.0    10.441259       -15009.0
# 15574    Zimbabwe  1961    3905034.0    10.094440            NaN
# 15575    Zimbabwe  1960    3776681.0          NaN            NaN
#
#        migration_perc iso3c iso2c               region  \
# 0                 NaN   ARB    1A           Aggregates
# 1           -0.003420   ARB    1A           Aggregates
# ...

# %% [markdown]
# # Data Preprocessing and Cleaning

# %%
data.head()
# Out:
#       country  year   population  pop_density  net_migration  migration_perc  \
# 0  Arab World  2018  419790588.0    37.372365            NaN             NaN
# 1  Arab World  2017  411898965.0    36.669804     -1408824.0        -0.00342
# 2  Arab World  2016  404024433.0    35.968764            NaN             NaN
# 3  Arab World  2015  396028278.0    35.256897            NaN             NaN
# 4  Arab World  2014  387907748.0    34.533978            NaN             NaN
#
#   iso3c iso2c      region adminregion incomeLevel lendingType capitalCity  \
# 0   ARB    1A  Aggregates         NaN  Aggregates  Aggregates         NaN
# 1   ARB    1A  Aggregates         NaN  Aggregates  Aggregates         NaN
# 2   ARB    1A  Aggregates         NaN  Aggregates  Aggregates         NaN
# 3   ARB    1A  Aggregates         NaN  Aggregates  Aggregates         NaN
# 4   ARB    1A  Aggregates         NaN  Aggregates  Aggregates         NaN
#
#    longitude  latitude
# 0        NaN       NaN
# ...

# %%
data.tail()
# Out:
#         country  year  population  pop_density  net_migration  migration_perc  \
# 15571  Zimbabwe  1964   4322861.0    11.174515            NaN             NaN
# 15572  Zimbabwe  1963   4178726.0    10.801928            NaN             NaN
# 15573  Zimbabwe  1962   4039201.0    10.441259       -15009.0       -0.003716
# 15574  Zimbabwe  1961   3905034.0    10.094440            NaN             NaN
# 15575  Zimbabwe  1960   3776681.0          NaN            NaN             NaN
#
#       iso3c iso2c               region  \
# 15571   ZWE    ZW  Sub-Saharan Africa
# 15572   ZWE    ZW  Sub-Saharan Africa
# 15573   ZWE    ZW  Sub-Saharan Africa
# 15574   ZWE    ZW  Sub-Saharan Africa
# 15575   ZWE    ZW  Sub-Saharan Africa
#
#                                       adminregion          incomeLevel  \
# 15571  Sub-Saharan Africa (excluding high income)  Lower middle income
# 15572  Sub-Saharan Africa (excluding high income)  Lower middle income
# ...

# %%
data.isnull().sum()
# Out:
# country               0
# year                  0
# population          167
# pop_density         746
# net_migration     12708
# migration_perc    12711
# iso3c               118
# iso2c               177
# region              118
# adminregion        7434
# incomeLevel         118
# lendingType         118
# capitalCity        3127
# longitude          3127
# latitude           3127
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# country           0
# year              0
# population        0
# pop_density       0
# net_migration     0
# migration_perc    0
# iso3c             0
# iso2c             0
# region            0
# adminregion       0
# incomeLevel       0
# lendingType       0
# capitalCity       0
# longitude         0
# latitude          0
# dtype: int64

# %%
data.head()
# Out:
#           country  year  population  pop_density  net_migration  \
# 2774  Afghanistan  2017  36296400.0    55.595993      -314602.0
# 2779  Afghanistan  2012  31161376.0    47.730564       521769.0
# 2784  Afghanistan  2007  27100536.0    41.510486     -1046361.0
# 2789  Afghanistan  2002  22600770.0    34.618096       744193.0
# 2794  Afghanistan  1997  19357126.0    29.649735      -867540.0
#
#       migration_perc iso3c iso2c      region adminregion incomeLevel  \
# 2774       -0.008668   AFG    AF  South Asia  South Asia  Low income
# 2779        0.016744   AFG    AF  South Asia  South Asia  Low income
# 2784       -0.038610   AFG    AF  South Asia  South Asia  Low income
# 2789        0.032928   AFG    AF  South Asia  South Asia  Low income
# 2794       -0.044818   AFG    AF  South Asia  South Asia  Low income
#
#      lendingType capitalCity  longitude  latitude
# 2774         IDA       Kabul    69.1761   34.5228
# 2779         IDA       Kabul    69.1761   34.5228
# ...

# %%
data.nunique()
# Out:
# country            128
# year                12
# population        1522
# pop_density       1522
# net_migration     1286
# migration_perc    1456
# iso3c              128
# iso2c              128
# region               6
# adminregion          6
# incomeLevel          3
# lendingType          4
# capitalCity        128
# longitude          128
# latitude           128
# dtype: int64

# %%
data.shape
# Out:
# (1522, 15)

# %%
data.index
# Out:
# Int64Index([ 2774,  2779,  2784,  2789,  2794,  2799,  2804,  2809,  2814,
#              2819,
#             ...
#             15528, 15533, 15538, 15543, 15548, 15553, 15558, 15563, 15568,
#             15573],
#            dtype='int64', length=1522)

# %%
data['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belize',
#        'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Central African Republic', 'Chad',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Cuba', 'Djibouti',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Fiji',
#        'Gabon', 'Gambia, The', 'Georgia', 'Ghana', 'Grenada', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'India',
#        'Indonesia', 'Iran, Islamic Rep.', 'Iraq', 'Jamaica', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Korea, Dem. People?? Rep.',
# ...

# %%
data.count()
# Out:
# country           1522
# year              1522
# population        1522
# pop_density       1522
# net_migration     1522
# migration_perc    1522
# iso3c             1522
# iso2c             1522
# region            1522
# adminregion       1522
# incomeLevel       1522
# lendingType       1522
# capitalCity       1522
# longitude         1522
# latitude          1522
# dtype: int64

# %%
data['country'].value_counts()
# Out:
# Afghanistan              12
# Montenegro               12
# Philippines              12
# Peru                     12
# Paraguay                 12
#                          ..
# Ecuador                  12
# Zimbabwe                 12
# Eritrea                  10
# Micronesia, Fed. Sts.     6
# Serbia                    6
# Name: country, Length: 128, dtype: int64

# %%
data.head()
# Out:
#           country  year  population  pop_density  net_migration  \
# 2774  Afghanistan  2017  36296400.0    55.595993      -314602.0
# 2779  Afghanistan  2012  31161376.0    47.730564       521769.0
# 2784  Afghanistan  2007  27100536.0    41.510486     -1046361.0
# 2789  Afghanistan  2002  22600770.0    34.618096       744193.0
# 2794  Afghanistan  1997  19357126.0    29.649735      -867540.0
#
#       migration_perc iso3c iso2c      region adminregion incomeLevel  \
# 2774       -0.008668   AFG    AF  South Asia  South Asia  Low income
# 2779        0.016744   AFG    AF  South Asia  South Asia  Low income
# 2784       -0.038610   AFG    AF  South Asia  South Asia  Low income
# 2789        0.032928   AFG    AF  South Asia  South Asia  Low income
# 2794       -0.044818   AFG    AF  South Asia  South Asia  Low income
#
#      lendingType capitalCity  longitude  latitude
# 2774         IDA       Kabul    69.1761   34.5228
# 2779         IDA       Kabul    69.1761   34.5228
# ...

# %%
data['region'].value_counts()
# Out:
# Sub-Saharan Africa            526
# Latin America & Caribbean     288
# Europe & Central Asia         234
# East Asia & Pacific           234
# Middle East & North Africa    144
# South Asia                     96
# Name: region, dtype: int64

# %%
data['adminregion'].value_counts()
# Out:
# Sub-Saharan Africa (excluding high income)            526
# Latin America & Caribbean (excluding high income)     288
# Europe & Central Asia (excluding high income)         234
# East Asia & Pacific (excluding high income)           234
# Middle East & North Africa (excluding high income)    144
# South Asia                                             96
# Name: adminregion, dtype: int64

# %%
data['pop_density'].value_counts()
# Out:
# 55.595993    1
# 72.959056    1
# 24.808783    1
# 28.711343    1
# 32.488541    1
#             ..
# 4.999864     1
# 5.714965     1
# 6.790399     1
# 8.013440     1
# 10.441259    1
# Name: pop_density, Length: 1522, dtype: int64

# %%
data['year'].value_counts()
# Out:
# 2007    128
# 2002    128
# 1997    128
# 1992    128
# 2017    127
# 2012    127
# 1987    126
# 1982    126
# 1977    126
# 1972    126
# 1967    126
# 1962    126
# Name: year, dtype: int64

# %% [markdown]
# # Data visualization

# %%
plt.bar(data['year'],data['population'],color='g',width=2)
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("population of united states over the years")
plt.show()

# %%
plt.hist(data['pop_density'],range=(0,100),bins=20,color='b',edgecolor='black')
plt.show()
