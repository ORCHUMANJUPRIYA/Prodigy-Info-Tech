# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset and Data preprocessing

# %%
data=pd.read_csv(r"E:\Kaggle datasets\bank.csv",delimiter=';')

# %%
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %% [markdown]
# # Data visualization

# %%
import seaborn as sns

# %%
data['y'].replace({'no':0,'yes':1},inplace=True)
ax = sns.countplot(x='y', data=data, palette='colorblind')
plt.title("Target Distribution")
total = data['y'].count()
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.1f}%')
plt.show()

# %%
ax=sns.countplot(x='month',data=data,palette='colorblind')
total=data['month'].count()
plt.title("'month' distribution")
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.1f}%')
plt.show()

# %%
data['month'].unique()
# Out:
# array(['oct', 'may', 'apr', 'jun', 'feb', 'aug', 'jan', 'jul', 'nov',
#        'sep', 'mar', 'dec'], dtype=object)

# %%
sns.set_style('whitegrid')
ax=sns.countplot(x='marital',data=data)
plt.title("sex Distribution")
total=data['month'].count()
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.1f}%')

plt.show()

# %%
sns.set_style("whitegrid")
ax=sns.countplot(x='education',data=data)
sns.color_palette("cubehelix", as_cmap=True)
total = data['education'].count()

# annotate the bars with fmt from matplotlib v3.7.0
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.1f}%')

plt.title("'Education' Distribution")
plt.show()

# %%
cor=data.corr()
sns.heatmap(cor,annot=True)
plt.show()
# Out:
# C:\Users\Lenovo l460\AppData\Local\Temp\ipykernel_13228\1785170454.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=data.corr()

# %%
sns.distplot(data['age'],bins=40)#distribution plot
sns.color_palette("Blues", as_cmap=True)
# Out:
# C:\Users\Lenovo l460\AppData\Local\Temp\ipykernel_13228\3183201296.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'],bins=40)#distribution plot

# %%
sns.set_style("whitegrid")
ax=sns.countplot(x='job',data=data)
total=data['job'].count()
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.1f}%')
plt.title("'job'Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_style("whitegrid")
ax=sns.countplot(x='default',data=data)
total=data['default'].count()
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.1f}%')
plt.title("'default'Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_style("whitegrid")
ax=sns.countplot(x='housing',data=data)
total=data['housing'].count()
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.1f}%')
plt.title("'housing'Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_style("whitegrid")
ax=sns.countplot(x='day',data=data)
total=data['day'].count()
ax.bar_label(ax.containers[0], fmt=lambda x: f'{(x/total)*100:0.1f}%')
plt.title("'day'Distribution")
plt.xticks(rotation=90)
plt.show()

# %%
data.hist(figsize=(10,10),color="blue")
plt.show()

# %%
sns.pairplot(data=data,vars=["age","balance","day","duration","pdays","previous"],hue="campaign")
plt.title("Pair plot")
plt.show()
